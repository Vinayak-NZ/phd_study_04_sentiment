# %%
if __name__ == '__main__':
# Out:
#   Cell In[1], line 1
#     if __name__ == '__main__':
#                               ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
import pandas as pd
import re
from wordcloud import WordCloud
import gensim
from gensim.utils import simple_preprocess
import gensim.corpora as corpora
import nltk
from nltk.corpus import stopwords
from pprint import pprint
import pyLDAvis.gensim
import pickle
import pyLDAvis

# %%
df = pd.read_csv("input/app_v1_feedback.txt", sep="\t", header=0, encoding = "latin1")

# %%
df.head()
# Out:
#    person_id  segment_id                                               text  \
# 0          1           1  Jetzt sehen Sie vermutlich die Startseite. OK....
# 1          1           2  Ja genau. Vielleicht hätte ich jetzt Lektion d...
# 2          1           3  OK, das heißt ich geb jetzt hier meine Initial...
# 3          1           4    Und den Code muss ich irgendwie kopieren, oder?
# 4          1           5  OK. Ach das steht auch da, muss ich mir nichts...
#
#         tags
# 0  {general}
# 1  {general}
# 2  {general}
# 3  {general}
# 4  {general}

# %%
df = df.drop(columns=['person_id', 'segment_id', 'tags'], 
             axis = 1)

# %%
df.head()
# Out:
#                                                 text
# 0  Jetzt sehen Sie vermutlich die Startseite. OK....
# 1  Ja genau. Vielleicht hätte ich jetzt Lektion d...
# 2  OK, das heißt ich geb jetzt hier meine Initial...
# 3    Und den Code muss ich irgendwie kopieren, oder?
# 4  OK. Ach das steht auch da, muss ich mir nichts...

# %%
df['text_processed'] = \
df['text'].map(lambda x: re.sub('[,\.!?]', '', x))
# Out:
# <>:2: DeprecationWarning: invalid escape sequence '\.'
# <>:2: DeprecationWarning: invalid escape sequence '\.'
# C:\Users\vanandkuma\AppData\Local\Temp\ipykernel_70804\3268311697.py:2: DeprecationWarning: invalid escape sequence '\.'
#   df['text'].map(lambda x: re.sub('[,\.!?]', '', x))

# %%
df['text_processed'] = \
df['text_processed'].map(lambda x: x.lower())

# %%
df['text_processed'].head()
# Out:
# 0    jetzt sehen sie vermutlich die startseite ok w...
# 1    ja genau vielleicht hätte ich jetzt lektion da...
# 2    ok das heißt ich geb jetzt hier meine initiale...
# 3        und den code muss ich irgendwie kopieren oder
# 4    ok ach das steht auch da muss ich mir nichts m...
# Name: text_processed, dtype: object

# %%
long_string = ','.join(list(df['text_processed'].values))

# %%
wordcloud = WordCloud(background_color = "white", max_words = 500, 
                      contour_width = 3, 
                      contour_color = 'steelblue')
# Out:
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:106: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.colormap = plt.cm.get_cmap(colormap)

# %%
wordcloud.generate(long_string)
# Out:
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# ...
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)
# C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:508: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   box_size = draw.textsize(word, font=transposed_font)

# %%
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
stop_words = stopwords.words('german')

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), 
                                             deacc = True))

# %%
def remove_stopwords(texts):
    return[[word for word in simple_preprocess(str(doc)) 
            if word not in stop_words] for doc in texts]

# %%
data = df.text_processed.values.tolist()
data_words = list(sent_to_words(data))

# %%
data_words = remove_stopwords(data_words)

# %%
#print(data_words)

# %%
id2word = corpora.Dictionary(data_words)

# %%
texts = data_words

# %%
corpus = [dict_.doc2bow(text) for text in texts]

# %%
#pprint(corpus)

# %%
num_topics = 3

# %%
lda_model = gensim.models.LdaMulticore(corpus = corpus, 
                                       id2word = id2word, 
                                       num_topics = num_topics)

# %%
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.027*"ja" + 0.024*"ok" + 0.019*"geburt" + 0.015*"sozusagen" + '
#   '0.015*"kommunikation" + 0.015*"gedacht" + 0.014*"nochmal" + 0.014*"immer" + '
#   '0.014*"fur" + 0.013*"ne"'),
#  (1,
#   '0.047*"ja" + 0.042*"ok" + 0.024*"genau" + 0.016*"gibt" + 0.013*"okay" + '
#   '0.012*"immer" + 0.012*"nochmal" + 0.011*"grundsatzlich" + 0.011*"lektion" + '
#   '0.011*"eher"'),
#  (2,
#   '0.030*"ok" + 0.015*"ja" + 0.014*"nochmal" + 0.014*"ach" + 0.014*"immer" + '
#   '0.014*"gut" + 0.012*"irgendwie" + 0.012*"geburt" + 0.012*"heißt" + '
#   '0.011*"registrieren"')]

# %%
pyLDAvis.enable_notebook()

LDAvis_data_filepath = 'output/ldavis_prepared_topics_three'

# %%
if 1 == 1:
    LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model, corpus, 
                                              id2word)
    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(LDAvis_prepared, f)
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\process_executor.py", line 391, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "C:\Users\vanandkuma\AppData\Local\Programs\Python\Python310\lib\multiprocessing\queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'pandas.core.indexes.numeric'
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[142], line 2
#       1 if 1 == 1:
# ----> 2     LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model, corpus,
#       3                                               id2word)
#       4     with open(LDAvis_data_filepath, 'wb') as f:
#       5         pickle.dump(LDAvis_prepared, f)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyLDAvis\gensim.py:123, in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#      78 """Transforms the Gensim TopicModel and related corpus and dictionary into
#      79 the data structures needed for the visualization.
#      80
#    (...)
#     120 See `pyLDAvis.prepare` for **kwargs.
#     121 """
#     122 opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 123 return vis_prepare(**opts)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyLDAvis\_prepare.py:432, in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics, start_index)
#     426 # Quick fix for red bar width bug.  We calculate the
#     427 # term frequencies internally, using the topic term distributions and the
#     428 # topic frequencies, rather than using the user-supplied term frequencies.
#     429 # For a detailed discussion, see: https://github.com/cpsievert/LDAvis/pull/41
#     430 term_frequency = np.sum(term_topic_freq, axis=0)
# --> 432 topic_info = _topic_info(topic_term_dists, topic_proportion,
#     433                          term_frequency, term_topic_freq, vocab, lambda_step, R,
#     434                          n_jobs, start_index)
#     435 token_table = _token_table(topic_info, term_topic_freq, vocab, term_frequency, start_index)
#     436 topic_coordinates = _topic_coordinates(mds, topic_term_dists, topic_proportion, start_index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyLDAvis\_prepare.py:273, in _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs, start_index)
#     262     df = pd.DataFrame({'Term': vocab[term_ix],
#     263                        'Freq': term_topic_freq.loc[original_topic_id, term_ix],
#     264                        'Total': term_frequency[term_ix],
#    (...)
#     267                        'loglift': log_lift.loc[original_topic_id, term_ix].round(4),
#     268                        })
#     269     return df.reindex(columns=[
#     270         "Term", "Freq", "Total", "Category", "logprob", "loglift"
#     271     ])
# --> 273 top_terms = pd.concat(Parallel(n_jobs=n_jobs)
#     274                       (delayed(_find_relevance_chunks)(log_ttd, log_lift, R, ls)
#     275                       for ls in _job_chunks(lambda_seq, n_jobs)))
#     276 topic_dfs = map(topic_top_term_df, enumerate(top_terms.T.iterrows(), start_index))
#     277 return pd.concat([default_term_info] + list(topic_dfs))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1056, in __call__(self, iterable)
#    1053 self._original_iterator = iterator
#    1054 if hasattr(pre_dispatch, 'endswith'):
#    1055     pre_dispatch = eval_expr(
# -> 1056         pre_dispatch.replace("n_jobs", str(n_jobs))
#    1057     )
#    1058 self._pre_dispatch_amount = pre_dispatch = int(pre_dispatch)
#    1060 # The main thread will consume the first pre_dispatch items and
#    1061 # the remaining items will later be lazily dispatched by async
#    1062 # callbacks upon task completions.
#    1063
#    1064 # TODO: this iterator should be batch_size * n_jobs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:935, in retrieve(self)
#     931     if _verbosity_filter(self.n_dispatched_batches, self.verbose):
#     932         return
#     933     self._print('Done %3i tasks      | elapsed: %s',
#     934                 (self.n_completed_tasks,
# --> 935                  short_format_time(elapsed_time), ))
#     936 else:
#     937     index = self.n_completed_tasks
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:542, in wrap_future_result(future, timeout)
#     539         warnings.warn(msg, stacklevel=3)
#     541     return 1
# --> 542 elif not (self.in_main_thread() or self.nesting_level == 0):
#     543     # Prevent posix fork inside in non-main posix threads
#     544     if n_jobs != 1:
#     545         warnings.warn(
#     546             'Loky-backed parallel loops cannot be nested below '
#     547             'threads, setting n_jobs=1',
#     548             stacklevel=3)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %%
with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 with open(LDAvis_data_filepath, 'rb') as f:
#       2     LDAvis_prepared = pickle.load(f)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/ldavis_prepared_topics_three'

# %%
pyLDAvis.save_html(LDAvis_prepared, 'output/ldavis_prepared_topics_three.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 pyLDAvis.save_html(LDAvis_prepared, 'output/ldavis_prepared_topics_three.html')
#
# NameError: name 'LDAvis_prepared' is not defined

# %%
LDAvis_prepared
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 LDAvis_prepared
#
# NameError: name 'LDAvis_prepared' is not defined
